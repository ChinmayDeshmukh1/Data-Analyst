# %%
Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\SQL\63. Dataset Customer Call List.xlsx.")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop(columns = 'Not_Useful_Column')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = 'Not_Useful_Column')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# 20      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.lstrip("...")
# Out:
# 0     nan
# 1     nan
# 2     nan
# 3     nan
# 4     nan
# 5     nan
# 6     nan
# 7     nan
# 8     nan
# 9     nan
# 10    nan
# 11    nan
# 12    nan
# 13    nan
# 14    nan
# 15    nan
# 16    nan
# 17    nan
# 18    nan
# 19    nan
# 20    nan
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.lstrip(["/","..."])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# Name: Last_Name, dtype: float64

# %%
df["Last_Name"] = df["Last_Name"].str.lstrip(["/","..."])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df["Last_Name"] = df["Last_Name"].str.lstrip(["/","..."])
#       2 df
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
# ...

# %%
#df["Last_Name"] = df["Last_Name"].str.lstrip("...")
#df["Last_Name"] = df["Last_Name"].str.lstrip("/")
#df["Last_Name"] = df["Last_Name"].str.lstrip("_")
# 1. Convert the column to string type, then clean it, and save it back to df
df["Last_Name"] = df["Last_Name"].astype(str).str.strip("123._/")
df
# Out:
#     CustomerID First_Name Last_Name  Phone_Number  \
# 0         1001      Frodo       nan  123-545-5421
# 1         1002       Abed       nan  123/643/9775
# 2         1003     Walter       nan    7066950392
# 3         1004     Dwight       nan  123-543-2345
# 4         1005        Jon       nan  876|678|3469
# 5         1006        Ron       nan  304-762-2467
# 6         1007       Jeff       nan           NaN
# 7         1008   Sherlock       nan  876|678|3469
# 8         1009    Gandalf       nan           N/a
# 9         1010      Peter       nan  123-545-5421
# 10        1011    Samwise       nan           NaN
# 11        1012      Harry       nan    7066950392
# 12        1013        Don       nan  123-543-2345
# 13        1014     Leslie       nan  876|678|3469
# 14        1015       Toby       nan  304-762-2467
# 15        1016        Ron       nan  123-545-5421
# 16        1017   Michael        nan  123/643/9775
# 17        1018      Clark       nan    7066950392
# ...

# %%
df
# Out:
#     CustomerID First_Name Last_Name  Phone_Number  \
# 0         1001      Frodo       nan  123-545-5421
# 1         1002       Abed       nan  123/643/9775
# 2         1003     Walter       nan    7066950392
# 3         1004     Dwight       nan  123-543-2345
# 4         1005        Jon       nan  876|678|3469
# 5         1006        Ron       nan  304-762-2467
# 6         1007       Jeff       nan           NaN
# 7         1008   Sherlock       nan  876|678|3469
# 8         1009    Gandalf       nan           N/a
# 9         1010      Peter       nan  123-545-5421
# 10        1011    Samwise       nan           NaN
# 11        1012      Harry       nan    7066950392
# 12        1013        Don       nan  123-543-2345
# 13        1014     Leslie       nan  876|678|3469
# 14        1015       Toby       nan  304-762-2467
# 15        1016        Ron       nan  123-545-5421
# 16        1017   Michael        nan  123/643/9775
# 17        1018      Clark       nan    7066950392
# ...

# %%
df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex = 'True')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex = 'True')
#       2 df
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
# ...

# %%
# 1. Force-remove any trailing or leading whitespace from all column names

# 2. Clean the phone numbers safely by enabling regex=True
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace('[^a-zA-Z0-9]','')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 4
#       1 # 1. Force-remove any trailing or leading whitespace from all column names
#       2
#       3 # 2. Clean the phone numbers safely by enabling regex=True
# ----> 4 df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace('[^a-zA-Z0-9]','')
#       5 df
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
# ...

# %%
# 1. Force-remove any trailing or leading whitespace from all column names

# 2. Clean the phone numbers safely by enabling regex=True
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace('[^a-zA-Z0-9]','')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 4
#       1 # 1. Force-remove any trailing or leading whitespace from all column names
#       2
#       3 # 2. Clean the phone numbers safely by enabling regex=True
# ----> 4 df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace('[^a-zA-Z0-9]','')
#       5 df
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
# ...

# %%
df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
# ...

# %%
df
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2              NaN
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11             NaN
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17             NaN
# 18             N/a
# 19    876|678|3469
# 20    876|678|3469
# Name: Phone_Number, dtype: object

# %%
str(df["Phone_Number"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 str(df["Phone_Number"])
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# ...

# %%
# Use .astype(str) on the variable directly, without brackets
df = df.astype(str).str.replace('[^a-zA-Z0-9]', '', regex=True)
df
# Out:
# 0     1235455421
# 1     1236439775
# 2            nan
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           nan
# 11           nan
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           nan
# 18            Na
# 19    8766783469
# 20    8766783469
# Name: Phone_Number, dtype: object

# %%
str(df["Phone_Number"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 str(df["Phone_Number"])
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# ...

# %%
df = df.to_frame(name="Phone_Number")
df
# Out:
#    Phone_Number
# 0    1235455421
# 1    1236439775
# 2           nan
# 3    1235432345
# 4    8766783469
# 5    3047622467
# 6           nan
# 7    8766783469
# 8            Na
# 9    1235455421
# 10          nan
# 11          nan
# 12   1235432345
# 13   8766783469
# 14   3047622467
# 15   1235455421
# 16   1236439775
# 17          nan
# 18           Na
# 19   8766783469
# 20   8766783469

# %%
df["Phone_Number"].apply(lambda x: str(x))
# Out:
# 0     1235455421
# 1     1236439775
# 2            nan
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           nan
# 11           nan
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           nan
# 18            Na
# 19    8766783469
# 20    8766783469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2            nan--
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6            nan--
# 7     876-678-3469
# 8             Na--
# 9     123-545-5421
# 10           nan--
# 11           nan--
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17           nan--
# 18            Na--
# 19    876-678-3469
# 20    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df
# Out:
#     Phone_Number
# 0   123---5-4-5-
# 1   123---6-4-3-
# 2      nan------
# 3   123---5-4-3-
# 4   876---6-7-8-
# 5   304---7-6-2-
# 6      nan------
# 7   876---6-7-8-
# 8       Na------
# 9   123---5-4-5-
# 10     nan------
# 11     nan------
# 12  123---5-4-3-
# 13  876---6-7-8-
# 14  304---7-6-2-
# 15  123---5-4-5-
# 16  123---6-4-3-
# 17     nan------
# 18      Na------
# 19  876---6-7-8-
# 20  876---6-7-8-

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')

df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
df
# Out:
#     Phone_Number
# 0   123---5-4-5-
# 1   123---6-4-3-
# 2           ----
# 3   123---5-4-3-
# 4   876---6-7-8-
# 5   304---7-6-2-
# 6           ----
# 7   876---6-7-8-
# 8           ----
# 9   123---5-4-5-
# 10          ----
# 11          ----
# 12  123---5-4-3-
# 13  876---6-7-8-
# 14  304---7-6-2-
# 15  123---5-4-5-
# 16  123---6-4-3-
# 17          ----
# 18          ----
# 19  876---6-7-8-
# 20  876---6-7-8-

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Address"].str.split(',',1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df["Address"].str.split(',',1)
#
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\strings\accessor.py:140, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
#     139     raise TypeError(msg)
# --> 140 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 were given

# %%
# Use the explicit keyword argument n=1
df["Address"].str.split(',', n=1)
# Out:
# 0                     [123 Shire Lane,  Shire]
# 1                        [93 West Main Street]
# 2                         [298 Drugs Driveway]
# 3     [980 Paper Avenue,  Pennsylvania, 18503]
# 4                           [123 Dragons Road]
# 5                           [768 City Parkway]
# 6                          [1209 South Street]
# 7                              [98 Clue Drive]
# 8                           [123 Middle Earth]
# 9                [25th Main Street,  New York]
# 10                    [612 Shire Lane,  Shire]
# 11                      [2394 Hogwarts Avenue]
# 12                          [2039 Main Street]
# 13                          [343 City Parkway]
# 14                             [214 HR Avenue]
# 15                      [2395 Hogwarts Avenue]
# 16           [121 Paper Avenue,  Pennsylvania]
# 17                           [3498 Super Lane]
# 18                                       [N/a]
# 19              [910 Tatooine Road,  Tatooine]
# ...

# %%
# Use the explicit keyword argument n=1
df["Address"].str.split(',', n=1, expand=True)
# Out:
#                        0                     1
# 0         123 Shire Lane                 Shire
# 1    93 West Main Street                  None
# 2     298 Drugs Driveway                  None
# 3       980 Paper Avenue   Pennsylvania, 18503
# 4       123 Dragons Road                  None
# 5       768 City Parkway                  None
# 6      1209 South Street                  None
# 7          98 Clue Drive                  None
# 8       123 Middle Earth                  None
# 9       25th Main Street              New York
# 10        612 Shire Lane                 Shire
# 11  2394 Hogwarts Avenue                  None
# 12      2039 Main Street                  None
# 13      343 City Parkway                  None
# 14         214 HR Avenue                  None
# 15  2395 Hogwarts Avenue                  None
# 16      121 Paper Avenue          Pennsylvania
# 17       3498 Super Lane                  None
# 18                   N/a                  None
# ...

# %%
# Use the explicit keyword argument n=1
df["Address"].str.split(',', n=2, expand=True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                   N/a           None    None
# ...

# %%
# Use the explicit keyword argument n=1
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(',', n=2, expand=True)
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Paying_Customer"].str.replace('Y','Yes')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Paying_Customer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ...

# %%
# Remove any accidental leading or trailing spaces from the headers
df.columns = df.columns.str.strip()

# Run your replacement code
df["Paying_Customer"] = df["Paying_Customer"].str.replace('Y', 'Yes')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Paying_Customer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 5
# ...

# %%
df.columns = df.columns.str.strip()
df["Paying_Customer"] = df["Paying_Customer"].str.replace('Y', 'Yes', regex=False)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\New folder\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Paying_Customer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
# ...

# %%
df = df.str.replace('Y', 'Yes', regex=False)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23628\3072994785.py in ?()
# ----> 1 df = df.str.replace('Y', 'Yes', regex=False)
#       2 df
#
# D:\Anaconda\New folder\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address', 'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column', 'Street_Address', 'State', 'Zip_Code']

# %%
df["Paying Customer"].str.replace('Y','Yes')

df["Paying Customer"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Do_Not_Contact"] = df["Paying Customer"].str.replace('Y','Yes')

df["Do_Not_Contact"] = df["Paying Customer"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.fillna('')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# ...

# %%
df = df.replace('N/a','')
df = df.replace('NaN','')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
         df.drop(x, inplace = True)

df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 18        1019      Creed       Braton
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
# ...

# %%
df["Do_Not_Contact"].str.replace('','N')
# Out:
# 0     NYNeNsN
# 1         NNN
# 2         NNN
# 3     NYNeNsN
# 5     NYNeNsN
# 6         NNN
# 7         NNN
# 8     NYNeNsN
# 9     NYNeNsN
# 10    NYNeNsN
# 12    NYNeNsN
# 13    NYNeNsN
# 14        NNN
# 15        NNN
# 16    NYNeNsN
# 18          N
# 19    NYNeNsN
# 20    NYNeNsN
# Name: Do_Not_Contact, dtype: object

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace = True)

df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876|678|3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes            Yes
# ...

# %%
df.reset_index()
# Out:
#     index  CustomerID First_Name    Last_Name  Phone_Number  \
# 0       0        1001      Frodo      Baggins  123-545-5421
# 1       1        1002       Abed        Nadir  123/643/9775
# 2       2        1003     Walter       /White    7066950392
# 3       3        1004     Dwight      Schrute  123-543-2345
# 4       5        1006        Ron      Swanson  304-762-2467
# 5       7        1008   Sherlock       Holmes  876|678|3469
# 6       9        1010      Peter       Parker  123-545-5421
# 7      12        1013        Don       Draper  123-543-2345
# 8      13        1014     Leslie        Knope  876|678|3469
# 9      14        1015       Toby  Flenderson_  304-762-2467
# 10     15        1016        Ron      Weasley  123-545-5421
# 11     16        1017   Michael         Scott  123/643/9775
# 12     19        1020     Anakin    Skywalker  876|678|3469
# 13     20        1020     Anakin    Skywalker  876|678|3469
#
# ...

# %%
df.reset_index()
# Out:
#     index  CustomerID First_Name    Last_Name  Phone_Number  \
# 0       0        1001      Frodo      Baggins  123-545-5421
# 1       1        1002       Abed        Nadir  123/643/9775
# 2       2        1003     Walter       /White    7066950392
# 3       3        1004     Dwight      Schrute  123-543-2345
# 4       5        1006        Ron      Swanson  304-762-2467
# 5       7        1008   Sherlock       Holmes  876|678|3469
# 6       9        1010      Peter       Parker  123-545-5421
# 7      12        1013        Don       Draper  123-543-2345
# 8      13        1014     Leslie        Knope  876|678|3469
# 9      14        1015       Toby  Flenderson_  304-762-2467
# 10     15        1016        Ron      Weasley  123-545-5421
# 11     16        1017   Michael         Scott  123/643/9775
# 12     19        1020     Anakin    Skywalker  876|678|3469
# 13     20        1020     Anakin    Skywalker  876|678|3469
#
# ...

# %%
df = df.reset_index(drop = True)
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1006        Ron      Swanson  304-762-2467
# 5         1008   Sherlock       Holmes  876|678|3469
# 6         1010      Peter       Parker  123-545-5421
# 7         1013        Don       Draper  123-543-2345
# 8         1014     Leslie        Knope  876|678|3469
# 9         1015       Toby  Flenderson_  304-762-2467
# 10        1016        Ron      Weasley  123-545-5421
# 11        1017   Michael         Scott  123/643/9775
# 12        1020     Anakin    Skywalker  876|678|3469
# 13        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes            Yes
# ...

# %%
for x in df.index:
    if df.loc[x, "Phonr_Number"] == '':
         df.drop(x, inplace = True)

df
df= df.dropna(subset = "Phone_Number"), inplace = True
# Out:
#   Cell In[107], line 6
#     df= df.dropna(subset = "Phone_Number"), inplace = True
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
