# %%
Functions

# %%
def function():
    print("My First Function") -> Function and Body

# %%
function() -> Function Call
My First Function -> Output

# %%
def first_func():
    print('We did it!')

# %%
first_func()
# Out:
# We did it!

# %%
def number_squared(number):
    print(number**2)

# %%
number_squared(number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 number_squared(number)
#
# NameError: name 'number' is not defined

# %%
number_squared(5)
# Out:
# 25

# %%
def number_squared_cust(number,power):
    print(number**power)

# %%
number_squared_cust(5,3)
# Out:
# 125

# %%
number_squared_cust(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 number_squared_cust(5)
#
# TypeError: number_squared_cust() missing 1 required positional argument: 'power'

# %%
def number_args(*number):
    print(number[0]*number[1])

# %%
number_args(5,6,1,2,8)
# Out:
# 30

# %%
args_tuple = (5,6,1,2,8)

def number_args(*number):
    print(number[0]*number[1])

# %%
number_args(args_tuple)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 number_args(args_tuple)
#
# Cell In[17], line 4, in number_args(*number)
#       3 def number_args(*number):
# ----> 4     print(number[0]*number[1])
#
# IndexError: tuple index out of range

# %%
number_args(*args_tuple)
# Out:
# 30

# %%
def number_squared_cust(number,power):
    print(number**power)

# %%
number_squared_cust(power = 5,number = 3)
# Out:
# 243

# %%
def number_kwarg(**number):
    print('My number is: ' + number['integer'])

# %%
number_kwarg(integer = 2309)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 number_kwarg(integer = 2309)
#
# Cell In[24], line 2, in number_kwarg(**number)
#       1 def number_kwarg(**number):
# ----> 2     print('My number is: ' + number['integer'])
#
# TypeError: can only concatenate str (not "int") to str

# %%
number_kwarg(integer = '2309')
# Out:
# My number is: 2309

# %%
def number_kwarg(**number):
    print('My number is: ' + number['integer'] + 'My other number: ' + number['integer2'])

# %%
number_kwarg(integer = '2309', integer2 = '349')
# Out:
# My number is: 2309My other number: 349
